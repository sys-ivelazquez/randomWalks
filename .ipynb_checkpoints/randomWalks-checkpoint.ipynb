# %% [markdown]
# # Homework 2
#
# **Name:** Silvia Ivonne Velázquez Ramírez
#
# **e-mail:** silvia.velazquez7499@alumnos.udg.mx

# %% [markdown]
# # Modules

# %%
import numpy as np
#import matplotlib.pyplot as plt
import plotly.graph_objects as go
from scipy.stats import cauchy

# %% [markdown]
# # Activity 1: Correlated Random Walk - 1 Trajectory

# %%
'''
# Number of steps
n_steps = 7500

# Correlation between steps
correlation = 0.9

# Generating a random walk
steps = np.random.randn(n_steps)
for i in range(1, n_steps):
    steps[i] += correlation * steps[i - 1]

# Generating the trajectory
trajectory = np.cumsum(steps)

# Plotting the trajectory
plt.plot(trajectory)
plt.title('Activity 1: Correlated Random Walk - 1 Trajectory')
plt.xlabel('Steps')
plt.ylabel('Position')
plt.show()
'''
class Vec2d:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y

    def add(self, vector):
        self.x += vector.x
        self.y += vector.y

    def get_position(self):
        return np.array([self.x, self.y])

# Number of steps
n_steps = 1000
correlation = 0.9
trajectory = []

# Initial position
current_position = Vec2d(0, 0)

# Generating the random walk
for i in range(n_steps):
    rotation_angle = cauchy.rvs(loc = 0, scale = correlation)
    step = Vec2d(np.cos(rotation_angle), np.sin(rotation_angle))
    current_position.add(step)
    trajectory.append(current_position.get_position())

# Converting the trajectory to numpy array
trajectory = np.array(trajectory)

# Plotting the results
fig = go.Figure()
fig.add_trace(go.Scatter(x = trajectory[:, 0], y = trajectory[:, 1], mode = 'lines'))
fig.update_layout(title = 'Activity 1: Correlated Random Walk - 1 Trajectory', xaxis_title = 'X', yaxis_title = 'Y')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 45
#      43 # Generating the random walk
#      44 for i in range(n_steps):
# ---> 45     rotation_angle = cauchy.rvs(loc = 0, scale = correlation)
#      46     step = Vec2d(np.cos(rotation_angle), np.sin(rotation_angle))
#      47     current_position.add(step)
#
# NameError: name 'cauchy' is not defined

# %% [markdown]
# # Activity 2: Lévy distribution - N different curves

# %%
# Number of curves
n_curves = 10

# Lévy index
index = 1.5

# Generating Lévy distribution
plt.figure(figsize = (10, 6))
for _ in range(n_curves):
    levy_steps = np.random.standard_t(df = index, size = 1000)
    plt.plot(np.cumsum(levy_steps), label = f'Curve {_ + 1}')

# Plotting results
plt.title('Activity 2: Lévy distribution - N different curves')
plt.xlabel('Steps')
plt.ylabel('Position')
plt.legend()
plt.show()

# %% [markdown]
# # Activity 3: Lévy distribution - Histogram + Curve

# %%
# Activity 3 here

# %% [markdown]
# # Activity 4: Lévy flight - Vec2d - 1 Trajectory

# %%
# Activity 4 here

# %% [markdown]
# # Activity 5: Correlated Random Walk - Vec2d - N Trajectories

# %%
# Activity 5 here
